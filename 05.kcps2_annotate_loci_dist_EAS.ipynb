# %%
import argparse
import requests
import numpy as np
import pandas as pd
import hail as hl
from hail.expr.functions import _sort_by
from hail.utils import hadoop_open, new_temp_file
import pyranges as pr
from ukbb_pan_ancestry import (
    get_distance_clumping_results_path,
    get_known_ukbb_loci_path,
    get_meta_analysis_results_path,
    get_munged_otg_v2d_path,
    get_munged_round2_path,
    get_pheno_manifest_path,
    get_ukb_pheno_efo_mapping_path,
    load_final_sumstats_mt,
    otg_release,
)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c894ce19-42b4-4bcb-b463-aee406d6b6cc">Loading BokehJS ...</span>
#     </div>

# %%
#--------------------------- 
# 09/20/2024
# expand 'region' to within 1Mb of lead variants
#---------------------------

# %%
def _to_pandas(ht):
            df = ht.to_pandas()
            # a temporary fix: cf. https://github.com/biocore-ntnu/pyranges/pull/264
            df = df.astype({k: "object" if v == "string[python]" else str(v).lower() for k, v in df.dtypes.items()})
            return df

# %%
# otg lead variants
#ht_v2d = hl.read_table("/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/munged_otg_v2d_no_exclusion.ht")
#ht_v2d = ht_v2d.annotate(
#    study_id=hl.delimit(ht_v2d.study_id),
#    Chromosome=ht_v2d.locus.contig,
#    Start=ht_v2d.locus.position,
#    End=ht_v2d.locus.position,
#)
#df_v2d = _to_pandas(ht_v2d)
print(df_v2d.head())
#gr_v2d = pr.PyRanges(df_v2d)
print(gr_v2d.head())
# Out:
#       locus    trait_efo           study_id                    trait_efo_term  \
# 0  1:768253  EFO_0006312       GCST90026371     mitochondrial DNA measurement
# 1  1:839538  EFO_0006865  NEALE2_20002_1202      urgency urinary incontinence
# 2  1:858051  EFO_0004617       GCST90025945            cystatin c measurement
# 3  1:891059  EFO_0004533       GCST90019494  alkaline phosphatase measurement
# 4  1:894573  EFO_0002618         GCST005434              pancreatic carcinoma
#
#          trait_efo_category Chromosome   Start     End
# 0         Other measurement          1  768253  768253
# 1               Other trait          1  839538  839538
# 2         Other measurement          1  858051  858051
# 3  Liver enzyme measurement          1  891059  891059
# 4                    Cancer          1  894573  894573
# +------------+-------------+----------------------------------+-------+
# | locus      | trait_efo   | study_id                         | +5    |
# | (object)   | (object)    | (object)                         | ...   |
# |------------+-------------+----------------------------------+-------|
# | 1:768253   | EFO_0006312 | GCST90026371                     | ...   |
# | 1:839538   | EFO_0006865 | NEALE2_20002_1202                | ...   |
# | 1:858051   | EFO_0004617 | GCST90025945                     | ...   |
# | 1:891059   | EFO_0004533 | GCST90019494                     | ...   |
# | 1:894573   | EFO_0002618 | GCST005434                       | ...   |
# | 1:894573   | EFO_0009270 | GCST90025982                     | ...   |
# | 1:895706   | EFO_0009270 | GCST006433,GCST006979,GCST007066 | ...   |
# | 1:896271   | EFO_0004533 | GCST90013406,GCST90025947        | ...   |
# +------------+-------------+----------------------------------+-------+
# Unstranded PyRanges object has 8 rows and 8 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 5 hidden columns: trait_efo_term, trait_efo_category, Chromosome, Start, End

# %%
trait = "ALCO_AMOUNT"
# kcps2 lead variants
df = pd.read_table(f"/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_loci/GenomicRiskLoci_{trait}.txt", delimiter="\t")
print(df)

# pyrange
gr = pr.PyRanges(df)
print(gr)
# Out:
#    idx    lead_locus                  region    trait_efo trait_efo_category  \
# 0    1    3:38052725     3:38052725-38052725  EFO_0007878  Other measurement
# 1    2   4:100239319   4:100000136-100336448  EFO_0007878  Other measurement
# 2    3    6:26207175     6:26180634-26326182  EFO_0007878  Other measurement
# 3    4  12:108700164  12:108248685-108701635  EFO_0007878  Other measurement
# 4    5  12:112241766  12:111414461-113117897  EFO_0007878  Other measurement
#
#    Chromosome      Start        End
# 0           3   38052725   38052725
# 1           4  100000136  100336448
# 2           6   26180634   26326182
# 3          12  108248685  108701635
# 4          12  111414461  113117897
# +-----------+--------------+------------------------+-------------+-------+
# |       idx | lead_locus   | region                 | trait_efo   | +4    |
# |   (int64) | (object)     | (object)               | (object)    | ...   |
# |-----------+--------------+------------------------+-------------+-------|
# |         1 | 3:38052725   | 3:38052725-38052725    | EFO_0007878 | ...   |
# |         2 | 4:100239319  | 4:100000136-100336448  | EFO_0007878 | ...   |
# |         3 | 6:26207175   | 6:26180634-26326182    | EFO_0007878 | ...   |
# |         4 | 12:108700164 | 12:108248685-108701635 | EFO_0007878 | ...   |
# |         5 | 12:112241766 | 12:111414461-113117897 | EFO_0007878 | ...   |
# +-----------+--------------+------------------------+-------------+-------+
# Unstranded PyRanges object has 5 rows and 8 columns from 4 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 4 hidden columns: trait_efo_category, Chromosome, Start, End
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
gr['4', 100000136:100336445]
# Out:
# +-----------+--------------+-----------------------+-------------+-------+
# |       idx | lead_locus   | region                | trait_efo   | +4    |
# |   (int64) | (object)     | (object)              | (object)    | ...   |
# |-----------+--------------+-----------------------+-------------+-------|
# |         2 | 4:100239319  | 4:100000136-100336448 | EFO_0007878 | ...   |
# +-----------+--------------+-----------------------+-------------+-------+
# Unstranded PyRanges object has 1 rows and 8 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 4 hidden columns: trait_efo_category, Chromosome, Start, End

# %%
df_annotated = gr.join(gr_v2d, how="left", suffix="_otg").as_df()
#df_annotated = df_annotated.drop(columns=["Chromosome", "Start", "End", "Start_otg", "End_otg"])
print(df_annotated)
# Out:
#       idx    lead_locus                  region    trait_efo  \
# 0       1    3:38052725     3:38052725-38052725  EFO_0007878
# 1       2   4:100239319   4:100000136-100336448  EFO_0007878
# 2       2   4:100239319   4:100000136-100336448  EFO_0007878
# 3       2   4:100239319   4:100000136-100336448  EFO_0007878
# 4       2   4:100239319   4:100000136-100336448  EFO_0007878
# ...   ...           ...                     ...          ...
# 1259    5  12:112241766  12:111414461-113117897  EFO_0007878
# 1260    5  12:112241766  12:111414461-113117897  EFO_0007878
# 1261    5  12:112241766  12:111414461-113117897  EFO_0007878
# 1262    5  12:112241766  12:111414461-113117897  EFO_0007878
# 1263    5  12:112241766  12:111414461-113117897  EFO_0007878
#
#      trait_efo_category Chromosome      Start        End         locus  \
# 0     Other measurement          3   38052725   38052725            -1
# 1     Other measurement          4  100000136  100336448   4:100006645
# 2     Other measurement          4  100000136  100336448   4:100009738
# 3     Other measurement          4  100000136  100336448   4:100009738
# 4     Other measurement          4  100000136  100336448   4:100010010
# ...                 ...        ...        ...        ...           ...
# 1259  Other measurement         12  111414461  113117897  12:113031543
# 1260  Other measurement         12  111414461  113117897  12:113031543
# 1261  Other measurement         12  111414461  113117897  12:113039943
# 1262  Other measurement         12  111414461  113117897  12:113064948
# 1263  Other measurement         12  111414461  113117897  12:113100994
#
#      trait_efo_otg      study_id  \
# 0               -1            -1
# 1      EFO_0004612  GCST90025956
# 2      EFO_0004696  GCST90012111
# 3      EFO_0004908  GCST90012113
# 4      EFO_0004908    GCST011518
# ...            ...           ...
# 1259   EFO_0004611    GCST010245
# 1260   EFO_0004615    GCST010243
# 1261   EFO_0004611    GCST010204
# 1262   EFO_0007985    GCST004607
# 1263   EFO_0004309    GCST001337
#
#                                         trait_efo_term  \
# 0                                                   -1
# 1     high density lipoprotein cholesterol measurement
# 2             sex hormone-binding globulin measurement
# 3                             testosterone measurement
# 4                             testosterone measurement
# ...                                                ...
# 1259   low density lipoprotein cholesterol measurement
# 1260                      apolipoprotein B measurement
# 1261   low density lipoprotein cholesterol measurement
# 1262                                     platelet crit
# 1263                                    platelet count
#
#                 trait_efo_category_otg  Start_otg    End_otg
# 0                                   -1         -1         -1
# 1     Lipid or lipoprotein measurement  100006645  100006645
# 2                    Other measurement  100009738  100009738
# 3     Lipid or lipoprotein measurement  100009738  100009738
# 4     Lipid or lipoprotein measurement  100010010  100010010
# ...                                ...        ...        ...
# 1259  Lipid or lipoprotein measurement  113031543  113031543
# 1260  Lipid or lipoprotein measurement  113031543  113031543
# 1261  Lipid or lipoprotein measurement  113039943  113039943
# 1262         Hematological measurement  113064948  113064948
# 1263         Hematological measurement  113100994  113100994
#
# [1264 rows x 15 columns]

# %%
ht_v2d = hl.read_table("/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/munged_otg_v2d_no_exclusion.ht")
ht_v2d.show(3)
# Out:
# +---------------+---------------+-----------------------+
# | locus         | trait_efo     | study_id              |
# +---------------+---------------+-----------------------+
# | locus<GRCh37> | str           | set<str>              |
# +---------------+---------------+-----------------------+
# | 1:768253      | "EFO_0006312" | {"GCST90026371"}      |
# | 1:839538      | "EFO_0006865" | {"NEALE2_20002_1202"} |
# | 1:858051      | "EFO_0004617" | {"GCST90025945"}      |
# +---------------+---------------+-----------------------+
#
# +---------------------------------+---------------------+
# | trait_efo_term                  | trait_efo_category  |
# +---------------------------------+---------------------+
# | str                             | str                 |
# +---------------------------------+---------------------+
# | "mitochondrial DNA measurement" | "Other measurement" |
# | "urgency urinary incontinence"  | "Other trait"       |
# | "cystatin c measurement"        | "Other measurement" |
# +---------------------------------+---------------------+
# showing top 3 rows

# %%
# otg lead variants
ht_v2d = hl.read_table("/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/munged_otg_v2d_no_exclusion.ht")
ht_v2d = ht_v2d.annotate(
    study_id=hl.delimit(ht_v2d.study_id),
    Chromosome=ht_v2d.locus.contig,
    Start=ht_v2d.locus.position,
    End=ht_v2d.locus.position,
)
ht_v2d.show(3)
# Out:
# +---------------+---------------+---------------------+
# | locus         | trait_efo     | study_id            |
# +---------------+---------------+---------------------+
# | locus<GRCh37> | str           | str                 |
# +---------------+---------------+---------------------+
# | 1:768253      | "EFO_0006312" | "GCST90026371"      |
# | 1:839538      | "EFO_0006865" | "NEALE2_20002_1202" |
# | 1:858051      | "EFO_0004617" | "GCST90025945"      |
# +---------------+---------------+---------------------+
#
# +---------------------------------+---------------------+------------+--------+
# | trait_efo_term                  | trait_efo_category  | Chromosome |  Start |
# +---------------------------------+---------------------+------------+--------+
# | str                             | str                 | str        |  int32 |
# +---------------------------------+---------------------+------------+--------+
# | "mitochondrial DNA measurement" | "Other measurement" | "1"        | 768253 |
# | "urgency urinary incontinence"  | "Other trait"       | "1"        | 839538 |
# | "cystatin c measurement"        | "Other measurement" | "1"        | 858051 |
# +---------------------------------+---------------------+------------+--------+
#
# +--------+
# |    End |
# +--------+
# |  int32 |
# +--------+
# | 768253 |
# | 839538 |
# | 858051 |
# +--------+
# showing top 3 rows

# %%
df_v2d = _to_pandas(ht_v2d)
print(df_v2d.head())
# Out:
# [Stage 26:>                                                         (0 + 2) / 2]
#       locus    trait_efo           study_id                    trait_efo_term  \
# 0  1:768253  EFO_0006312       GCST90026371     mitochondrial DNA measurement
# 1  1:839538  EFO_0006865  NEALE2_20002_1202      urgency urinary incontinence
# 2  1:858051  EFO_0004617       GCST90025945            cystatin c measurement
# 3  1:891059  EFO_0004533       GCST90019494  alkaline phosphatase measurement
# 4  1:894573  EFO_0002618         GCST005434              pancreatic carcinoma
#
#          trait_efo_category Chromosome   Start     End
# 0         Other measurement          1  768253  768253
# 1               Other trait          1  839538  839538
# 2         Other measurement          1  858051  858051
# 3  Liver enzyme measurement          1  891059  891059
# 4                    Cancer          1  894573  894573

# %%
#========== EAS biobanks as ref ===========#
ht_v2d = hl.import_table("/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/GWAS_Catalog/KoGES_otg_form.txt", delimiter='\t', impute=True)

# Strip the "Chr" prefix from the locus string (e.g., "Chr2:27730940" -> "2:27730940")
ht_v2d = ht_v2d.annotate(locus_stripped = hl.str(ht_v2d.locus).replace("^Chr", ""))

# Parse the modified locus field to a proper Hail locus object
ht_v2d = ht_v2d.annotate(locus = hl.parse_locus(ht_v2d.locus_stripped, reference_genome='GRCh37'))

# Now you can access the contig and position attributes
ht_v2d = ht_v2d.annotate(
    study_id = ht_v2d.study_id,
    Chromosome = ht_v2d.locus.contig,
    Start = ht_v2d.locus.position,
    End = ht_v2d.locus.position
)
df_v2d = _to_pandas(ht_v2d)
print(df_v2d.head())
# Out:
#          locus    trait_efo      study_id trait_efo_term trait_efo_category  \
# 0  15:89804417  EFO_0004339  GCST90255478    body height        body height
# 1  15:90141591  EFO_0004339  GCST90255478    body height        body height
# 2  15:90619081  EFO_0004339  GCST90255478    body height        body height
# 3  15:99192483  EFO_0004339  GCST90255478    body height        body height
# 4  15:99240993  EFO_0004339  GCST90255478    body height        body height
#
#   locus_stripped Chromosome     Start       End
# 0    15:89804417         15  89804417  89804417
# 1    15:90141591         15  90141591  90141591
# 2    15:90619081         15  90619081  90619081
# 3    15:99192483         15  99192483  99192483
# 4    15:99240993         15  99240993  99240993

# %%
def annotate_known_loci_1Mb_EAS(trait):

    #========== EAS biobanks as ref ===========#
    ht_v2d = hl.import_table("/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/GWAS_Catalog/KoGES_TWB_otg_form.txt", delimiter='\t', impute=True)

    # Strip the "Chr" prefix from the locus string (e.g., "Chr2:27730940" -> "2:27730940")
    #ht_v2d = ht_v2d.annotate(locus_stripped=hl.str(ht_v2d.locus).replace("^Chr", ""))
    
    # Replace '23' with 'X' before parsing the locus
    ht_v2d = ht_v2d.annotate(
        locus=hl.if_else(ht_v2d.locus.startswith("23:"), 
                                  hl.str(ht_v2d.locus).replace("23:", "X:"), 
                                  ht_v2d.locus)
    )
    
    # Parse the modified locus field to a proper Hail locus object
    ht_v2d = ht_v2d.annotate(locus=hl.parse_locus(ht_v2d.locus, reference_genome='GRCh37'))
    
    # Now you can access the contig and position attributes
    ht_v2d = ht_v2d.annotate(
        study_id = ht_v2d.study_id,
        Chromosome = ht_v2d.locus.contig,
        Start = ht_v2d.locus.position,
        End = ht_v2d.locus.position
    )
    
    df_v2d = _to_pandas(ht_v2d)
    #print(df_v2d.head())

    # kcps2 lead variants
    df = pd.read_table(f"/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_loci/GenomicRiskLoci_{trait}_1Mb.txt", delimiter="\t")
    #print(df.head())
    
    # pyrange
    gr = pr.PyRanges(df)
    #print(gr.head())

    gr_v2d = pr.PyRanges(df_v2d)
    #print(gr_v2d.head())

    df_annotated = gr.join(gr_v2d, how="left", suffix="_otg").as_df()
    df_annotated = df_annotated.drop(columns=["Chromosome", "Start", "End", "Start_otg", "End_otg"])

    # write out and read back b/c hl.Table.from_pandas is extreamly slow
    tmpfile = new_temp_file()
    with hadoop_open(tmpfile, "wb") as f:
        df_annotated.to_csv(f, sep="\t", na_rep="NA", index=False)

    ht = hl.import_table(tmpfile, impute=True, min_partitions=1000)
    ht = ht.rename({"locus": "locus_otg", "study_id": "study_id_otg"})
    ht = ht.annotate(
        **{
            key: hl.if_else(ht[key] == "-1", hl.missing(hl.tstr), ht[key])
            for key in filter(lambda x: x.endswith("_otg"), list(ht.row))
        }
    )
    ht = ht.annotate(
        lead_locus=hl.parse_locus(ht.lead_locus),
        region=hl.parse_locus_interval(ht.region),
        locus=hl.parse_locus(ht.locus_otg),
        study_id_otg=ht.study_id_otg.split(","),
    )
    ht.show(3)

    for field in ["trait_efo", "trait_efo_category"]:
        x = df_annotated[~df_annotated[field].isna()]
        known_idx = set(x[x[field] == x[f"{field}_otg"]].idx)
        novel_idx = set(x.idx) - set(known_idx)
        na_idx = set(df_annotated.idx) - set(x.idx)
        na_match = na_idx.intersection(
            set(df_annotated[df_annotated[field].isna() & ~df_annotated.locus.isna()].idx)
        )
        k = "efo" if field == "trait_efo" else "efo_category"
        ht = ht.annotate(
            **{
                f"is_known_{k}": hl.case()
                #.when(hl.set(known_idx).contains(ht.idx), True)
                #.when(hl.set(novel_idx).contains(ht.idx), False)
                .when(hl.set(known_idx if len(known_idx) > 0 else hl.empty_set(ht.idx.dtype)).contains(ht.idx), True)
                .when(hl.set(novel_idx if len(novel_idx) > 0 else hl.empty_set(ht.idx.dtype)).contains(ht.idx), False)
                .default(hl.missing(hl.tbool))
            }
        )
        print(field)
        # category known
        print(len(known_idx))
        # category novel
        print(len(novel_idx))
        # category NA
        print(len(na_idx))
        # category NA match
        print(len(na_match))
        
    #N_novel = len(novel_idx)
    #N_novel_cat = len(novel_idx)
    #res_count = pd.DataFrame({'trait': [trait], 'Number of loci': [N_total], 'Number of novel loci': [N_unrep]})
    
    ht.export(f"/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_otg/known_kcps2_loci_{trait}_1Mb_EAS.tsv")

# %%
def annotate_known_loci_500kb_EAS(trait):

    #========== EAS biobanks as ref ===========#
    ht_v2d = hl.import_table("/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/GWAS_Catalog/KoGES_TWB_otg_form.txt", delimiter='\t', impute=True)

    # Strip the "Chr" prefix from the locus string (e.g., "Chr2:27730940" -> "2:27730940")
    #ht_v2d = ht_v2d.annotate(locus_stripped=hl.str(ht_v2d.locus).replace("^Chr", ""))
    
    # Replace '23' with 'X' before parsing the locus
    ht_v2d = ht_v2d.annotate(
        locus=hl.if_else(ht_v2d.locus.startswith("23:"), 
                                  hl.str(ht_v2d.locus).replace("23:", "X:"), 
                                  ht_v2d.locus)
    )
    
    # Parse the modified locus field to a proper Hail locus object
    ht_v2d = ht_v2d.annotate(locus=hl.parse_locus(ht_v2d.locus, reference_genome='GRCh37'))
    
    # Now you can access the contig and position attributes
    ht_v2d = ht_v2d.annotate(
        study_id = ht_v2d.study_id,
        Chromosome = ht_v2d.locus.contig,
        Start = ht_v2d.locus.position,
        End = ht_v2d.locus.position
    )
    df_v2d = _to_pandas(ht_v2d)
    #print(df_v2d.head())

    # kcps2 lead variants
    df = pd.read_table(f"/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_loci/GenomicRiskLoci_{trait}_500kb.txt", delimiter="\t")
    #print(df.head())
    
    # pyrange
    gr = pr.PyRanges(df)
    #print(gr.head())

    gr_v2d = pr.PyRanges(df_v2d)
    #print(gr_v2d.head())

    df_annotated = gr.join(gr_v2d, how="left", suffix="_otg").as_df()
    df_annotated = df_annotated.drop(columns=["Chromosome", "Start", "End", "Start_otg", "End_otg"])

    # write out and read back b/c hl.Table.from_pandas is extreamly slow
    tmpfile = new_temp_file()
    with hadoop_open(tmpfile, "wb") as f:
        df_annotated.to_csv(f, sep="\t", na_rep="NA", index=False)

    ht = hl.import_table(tmpfile, impute=True, min_partitions=1000)
    ht = ht.rename({"locus": "locus_otg", "study_id": "study_id_otg"})
    ht = ht.annotate(
        **{
            key: hl.if_else(ht[key] == "-1", hl.missing(hl.tstr), ht[key])
            for key in filter(lambda x: x.endswith("_otg"), list(ht.row))
        }
    )
    ht = ht.annotate(
        lead_locus=hl.parse_locus(ht.lead_locus),
        region=hl.parse_locus_interval(ht.region),
        locus=hl.parse_locus(ht.locus_otg),
        study_id_otg=ht.study_id_otg.split(","),
    )
    ht.show(3)

    for field in ["trait_efo", "trait_efo_category"]:
        x = df_annotated[~df_annotated[field].isna()]
        known_idx = set(x[x[field] == x[f"{field}_otg"]].idx)
        novel_idx = set(x.idx) - set(known_idx)
        na_idx = set(df_annotated.idx) - set(x.idx)
        na_match = na_idx.intersection(
            set(df_annotated[df_annotated[field].isna() & ~df_annotated.locus.isna()].idx)
        )
        k = "efo" if field == "trait_efo" else "efo_category"
        ht = ht.annotate(
            **{
                f"is_known_{k}": hl.case()
                #.when(hl.set(known_idx).contains(ht.idx), True)
                #.when(hl.set(novel_idx).contains(ht.idx), False)
                .when(hl.set(known_idx if len(known_idx) > 0 else hl.empty_set(ht.idx.dtype)).contains(ht.idx), True)
                .when(hl.set(novel_idx if len(novel_idx) > 0 else hl.empty_set(ht.idx.dtype)).contains(ht.idx), False)
                .default(hl.missing(hl.tbool))
            }
        )
        print(field)
        # category known
        print(len(known_idx))
        # category novel
        print(len(novel_idx))
        # category NA
        print(len(na_idx))
        # category NA match
        print(len(na_match))
        
    #N_novel = len(novel_idx)
    #N_novel_cat = len(novel_idx)
    #res_count = pd.DataFrame({'trait': [trait], 'Number of loci': [N_total], 'Number of novel loci': [N_unrep]})
    
    ht.export(f"/n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_otg/known_kcps2_loci_{trait}_500kb_EAS.tsv")

# %%
## 1Mb

# %%
trait_list = ["LDL", "TG", "HDL", "CHO", "FBS", "INSULIN","GOT", "GPT", "GGT", "BIL", "ALB","TSH", "CEA","CREAT","ADIPO","URIC", "ALP","HB", "HCT", "MCH", "MCHC", "MCV","RBC", "RDW", "WBC","PLT", "EOS", "SBP", "DBP", "WT",
              "HEIGHT", "BMI", "WAIST", "SMOKA_MOD", "ALCO_AMOUNT","COFFA"]
res = pd.DataFrame()
for i in range(len(trait_list)):
    trait = trait_list[i]
    print(trait)
    annotate_known_loci_1Mb_EAS(trait)
# Out:
# LDL
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 29:====================================================>(987 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16505320    | [1:15505320-1:17505320) | "EFO_0004611" |
# |     1 | 1:16505320    | [1:15505320-1:17505320) | "EFO_0004611" |
# |     1 | 1:16505320    | [1:15505320-1:17505320) | "EFO_0004611" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:15539259" | "EFO_0004518" |
# | "Lipid or lipoprotein measurement" | "1:15782677" | "EFO_0004518" |
# | "Lipid or lipoprotein measurement" | "1:15816768" | "EFO_0004518" |
# +------------------------------------+--------------+---------------+
#
# +------------------+--------------------------+--------------------------+
# | study_id_otg     | trait_efo_term           | trait_efo_category_otg   |
# +------------------+--------------------------+--------------------------+
# | array<str>       | str                      | str                      |
# +------------------+--------------------------+--------------------------+
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# +------------------+--------------------------+--------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:15539259    |
# | 1:15782677    |
# | 1:15816768    |
# +---------------+
# showing top 3 rows
# trait_efo
# 62
# 46
# 0
# 0
# trait_efo_category
# 0
# 108
# 0
# 0
# [Stage 33:====================================================>(989 + 2) / 1000]
# TG
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 40:===================================================> (970 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:63145439    | [1:62145439-1:64145439) | "EFO_0004530" |
# |     1 | 1:63145439    | [1:62145439-1:64145439) | "EFO_0004530" |
# |     1 | 1:63145439    | [1:62145439-1:64145439) | "EFO_0004530" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:62853713" | "EFO_0004530" |
# | "Lipid or lipoprotein measurement" | "1:62853713" | "EFO_0004530" |
# | "Lipid or lipoprotein measurement" | "1:63043657" | "EFO_0004530" |
# +------------------------------------+--------------+---------------+
#
# +------------------+----------------------------+----------------------------+
# | study_id_otg     | trait_efo_term             | trait_efo_category_otg     |
# +------------------+----------------------------+----------------------------+
# | array<str>       | str                        | str                        |
# +------------------+----------------------------+----------------------------+
# | ["GCST90255493"] | "triglyceride measurement" | "triglyceride measurement" |
# | ["GCST90255426"] | "triglyceride measurement" | "triglyceride measurement" |
# | ["GCST90255493"] | "triglyceride measurement" | "triglyceride measurement" |
# +------------------+----------------------------+----------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:62853713    |
# | 1:62853713    |
# | 1:63043657    |
# +---------------+
# showing top 3 rows
# trait_efo
# 53
# 27
# 0
# 0
# trait_efo_category
# 0
# 80
# 0
# 0
# [Stage 44:===================================================> (978 + 2) / 1000]
# HDL
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 51:===================================================> (981 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:40064961    | [1:39064961-1:41064961) | "EFO_0004612" |
# |     1 | 1:40064961    | [1:39064961-1:41064961) | "EFO_0004612" |
# |     1 | 1:40064961    | [1:39064961-1:41064961) | "EFO_0004612" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:39457006" | "EFO_0004612" |
# | "Lipid or lipoprotein measurement" | "1:39976059" | "EFO_0000400" |
# | "Lipid or lipoprotein measurement" | "1:39976076" | "EFO_0004541" |
# +------------------------------------+--------------+---------------+
#
# +------------------+----------------------------------------------------+
# | study_id_otg     | trait_efo_term                                     |
# +------------------+----------------------------------------------------+
# | array<str>       | str                                                |
# +------------------+----------------------------------------------------+
# | ["GCST90255491"] | "high density lipoprotein cholesterol measurement" |
# | ["GCST90255468"] | "diabetes mellitus"                                |
# | ["GCST90278632"] | "HbA1c measurement"                                |
# +------------------+----------------------------------------------------+
#
# +----------------------------------------------------+---------------+
# | trait_efo_category_otg                             | locus         |
# +----------------------------------------------------+---------------+
# | str                                                | locus<GRCh37> |
# +----------------------------------------------------+---------------+
# | "high density lipoprotein cholesterol measurement" | 1:39457006    |
# | "diabetes mellitus"                                | 1:39976059    |
# | "HbA1c measurement"                                | 1:39976076    |
# +----------------------------------------------------+---------------+
# showing top 3 rows
# trait_efo
# 53
# 9
# 0
# 0
# trait_efo_category
# 0
# 62
# 0
# 0
# [Stage 55:===================================================> (980 + 2) / 1000]
# CHO
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 62:====================================================>(986 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:25829988    | [1:24829988-1:26829988) | "EFO_0004574" |
# |     1 | 1:25829988    | [1:24829988-1:26829988) | "EFO_0004574" |
# |     1 | 1:25829988    | [1:24829988-1:26829988) | "EFO_0004574" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:25051102" | "EFO_0004309" |
# | "Lipid or lipoprotein measurement" | "1:25607316" | "EFO_0004541" |
# | "Lipid or lipoprotein measurement" | "1:25611035" | "EFO_0004541" |
# +------------------------------------+--------------+---------------+
#
# +------------------+---------------------+------------------------+
# | study_id_otg     | trait_efo_term      | trait_efo_category_otg |
# +------------------+---------------------+------------------------+
# | array<str>       | str                 | str                    |
# +------------------+---------------------+------------------------+
# | ["GCST90278640"] | "platelet count"    | "platelet count"       |
# | ["GCST90255414"] | "HbA1c measurement" | "HbA1c measurement"    |
# | ["GCST90255481"] | "HbA1c measurement" | "HbA1c measurement"    |
# +------------------+---------------------+------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:25051102    |
# | 1:25607316    |
# | 1:25611035    |
# +---------------+
# showing top 3 rows
# trait_efo
# 82
# 59
# 0
# 0
# trait_efo_category
# 0
# 141
# 0
# 0
# [Stage 66:====================================================>(989 + 2) / 1000]
# FBS
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 73:===================================================> (964 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:43453188    | [1:42453188-1:44453188) | "EFO_0004468" |
# |     1 | 1:43453188    | [1:42453188-1:44453188) | "EFO_0004468" |
# |     1 | 1:43453188    | [1:42453188-1:44453188) | "EFO_0004468" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:43455283" | "EFO_0004465" | ["GCST90278628"] |
# | "Other measurement" | "1:43805737" | "EFO_0004308" | ["GCST90278647"] |
# | "Other measurement" | "1:43884714" | "EFO_0004309" | ["GCST90255498"] |
# +---------------------+--------------+---------------+------------------+
#
# +-------------------------------------+-------------------------------------+
# | trait_efo_term                      | trait_efo_category_otg              |
# +-------------------------------------+-------------------------------------+
# | str                                 | str                                 |
# +-------------------------------------+-------------------------------------+
# | "fasting blood glucose measurement" | "fasting blood glucose measurement" |
# | "leukocyte count"                   | "leukocyte count"                   |
# | "platelet count"                    | "platelet count"                    |
# +-------------------------------------+-------------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:43455283    |
# | 1:43805737    |
# | 1:43884714    |
# +---------------+
# showing top 3 rows
# trait_efo
# 47
# 40
# 0
# 0
# trait_efo_category
# 0
# 87
# 0
# 0
# [Stage 77:===================================================> (972 + 2) / 1000]
# INSULIN
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 84:===================================================> (977 + 3) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 2:27730940    | [2:26730940-2:28730940) | "EFO_0004467" |
# |     1 | 2:27730940    | [2:26730940-2:28730940) | "EFO_0004467" |
# |     1 | 2:27730940    | [2:26730940-2:28730940) | "EFO_0004467" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "2:26909432" | "EFO_0006336" | ["GCST90278625"] |
# | "Other measurement" | "2:26915624" | "EFO_0006335" | ["GCST90255406"] |
# | "Other measurement" | "2:26915624" | "EFO_0006336" | ["GCST90255477"] |
# +---------------------+--------------+---------------+------------------+
#
# +----------------------------+----------------------------+---------------+
# | trait_efo_term             | trait_efo_category_otg     | locus         |
# +----------------------------+----------------------------+---------------+
# | str                        | str                        | locus<GRCh37> |
# +----------------------------+----------------------------+---------------+
# | "diastolic blood pressure" | "diastolic blood pressure" | 2:26909432    |
# | "systolic blood pressure"  | "systolic blood pressure"  | 2:26915624    |
# | "diastolic blood pressure" | "diastolic blood pressure" | 2:26915624    |
# +----------------------------+----------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 6
# 0
# 0
# trait_efo_category
# 0
# 6
# 0
# 0
# [Stage 89:====================================================>(982 + 2) / 1000]
# GOT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 96:==================================================>  (950 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16516585    | [1:15516585-1:17516585) | "EFO_0004736" |
# |     1 | 1:16516585    | [1:15516585-1:17516585) | "EFO_0004736" |
# |     1 | 1:16516585    | [1:15516585-1:17516585) | "EFO_0004736" |
# +-------+---------------+-------------------------+---------------+
#
# +----------------------------+--------------+---------------+------------------+
# | trait_efo_category         | locus_otg    | trait_efo_otg | study_id_otg     |
# +----------------------------+--------------+---------------+------------------+
# | str                        | str          | str           | array<str>       |
# +----------------------------+--------------+---------------+------------------+
# | "Liver enzyme measurement" | "1:15539259" | "EFO_0004518" | ["GCST90255485"] |
# | "Liver enzyme measurement" | "1:15782677" | "EFO_0004518" | ["GCST90255485"] |
# | "Liver enzyme measurement" | "1:15816768" | "EFO_0004518" | ["GCST90255485"] |
# +----------------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "creatinine measurement" | "creatinine measurement" | 1:15539259    |
# | "creatinine measurement" | "creatinine measurement" | 1:15782677    |
# | "creatinine measurement" | "creatinine measurement" | 1:15816768    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 42
# 28
# 0
# 0
# trait_efo_category
# 0
# 70
# 0
# 0
# [Stage 100:===================================================>(982 + 2) / 1000]
# GPT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 107:==================================================> (979 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:31886498    | [1:30886498-1:32886498) | "EFO_0004735" |
# |     1 | 1:31886498    | [1:30886498-1:32886498) | "EFO_0004735" |
# |     1 | 1:31886498    | [1:30886498-1:32886498) | "EFO_0004735" |
# +-------+---------------+-------------------------+---------------+
#
# +----------------------------+--------------+---------------+------------------+
# | trait_efo_category         | locus_otg    | trait_efo_otg | study_id_otg     |
# +----------------------------+--------------+---------------+------------------+
# | str                        | str          | str           | array<str>       |
# +----------------------------+--------------+---------------+------------------+
# | "Liver enzyme measurement" | "1:31707354" | "EFO_0004518" | ["GCST90255485"] |
# | "Liver enzyme measurement" | "1:31872750" | "EFO_0004736" | ["GCST90255486"] |
# | "Liver enzyme measurement" | "1:31881152" | "EFO_0004735" | ["GCST90255488"] |
# +----------------------------+--------------+---------------+------------------+
#
# +----------------------------------------------+
# | trait_efo_term                               |
# +----------------------------------------------+
# | str                                          |
# +----------------------------------------------+
# | "creatinine measurement"                     |
# | "aspartate aminotransferase measurement"     |
# | "serum alanine aminotransferase measurement" |
# +----------------------------------------------+
#
# +----------------------------------------------+---------------+
# | trait_efo_category_otg                       | locus         |
# +----------------------------------------------+---------------+
# | str                                          | locus<GRCh37> |
# +----------------------------------------------+---------------+
# | "creatinine measurement"                     | 1:31707354    |
# | "aspartate aminotransferase measurement"     | 1:31872750    |
# | "serum alanine aminotransferase measurement" | 1:31881152    |
# +----------------------------------------------+---------------+
# showing top 3 rows
# trait_efo
# 40
# 28
# 0
# 0
# trait_efo_category
# 0
# 68
# 0
# 0
# [Stage 111:==================================================> (977 + 2) / 1000]
# GGT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 118:=================================================>  (960 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16505320    | [1:15505320-1:17505320) | "EFO_0004532" |
# |     1 | 1:16505320    | [1:15505320-1:17505320) | "EFO_0004532" |
# |     1 | 1:16505320    | [1:15505320-1:17505320) | "EFO_0004532" |
# +-------+---------------+-------------------------+---------------+
#
# +----------------------------+--------------+---------------+------------------+
# | trait_efo_category         | locus_otg    | trait_efo_otg | study_id_otg     |
# +----------------------------+--------------+---------------+------------------+
# | str                        | str          | str           | array<str>       |
# +----------------------------+--------------+---------------+------------------+
# | "Liver enzyme measurement" | "1:15539259" | "EFO_0004518" | ["GCST90255485"] |
# | "Liver enzyme measurement" | "1:15782677" | "EFO_0004518" | ["GCST90255485"] |
# | "Liver enzyme measurement" | "1:15816768" | "EFO_0004518" | ["GCST90255485"] |
# +----------------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "creatinine measurement" | "creatinine measurement" | 1:15539259    |
# | "creatinine measurement" | "creatinine measurement" | 1:15782677    |
# | "creatinine measurement" | "creatinine measurement" | 1:15816768    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 77
# 27
# 0
# 0
# trait_efo_category
# 0
# 104
# 0
# 0
# [Stage 122:===================================================>(988 + 2) / 1000]
# BIL
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 129:==================================================> (969 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 1:156245606   | [1:155245606-1:157245606) | "EFO_0004570" |
# |     1 | 1:156245606   | [1:155245606-1:157245606) | "EFO_0004570" |
# |     1 | 1:156245606   | [1:155245606-1:157245606) | "EFO_0004570" |
# +-------+---------------+---------------------------+---------------+
#
# +---------------------+---------------+---------------+------------------+
# | trait_efo_category  | locus_otg     | trait_efo_otg | study_id_otg     |
# +---------------------+---------------+---------------+------------------+
# | str                 | str           | str           | array<str>       |
# +---------------------+---------------+---------------+------------------+
# | "Other measurement" | "1:155485027" | "EFO_0004305" | ["GCST90255428"] |
# | "Other measurement" | "1:155485027" | "EFO_0004348" | ["GCST90255430"] |
# | "Other measurement" | "1:155485027" | "EFO_0004509" | ["GCST90255429"] |
# +---------------------+---------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "erythrocyte count"      | "erythrocyte count"      | 1:155485027   |
# | "hematocrit"             | "hematocrit"             | 1:155485027   |
# | "hemoglobin measurement" | "hemoglobin measurement" | 1:155485027   |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 24
# 21
# 0
# 0
# trait_efo_category
# 0
# 45
# 0
# 0
# [Stage 133:===================================================>(985 + 3) / 1000]
# ALB
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 140:=================================================>  (954 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16528218    | [1:15528218-1:17528218) | "EFO_0004535" |
# |     1 | 1:16528218    | [1:15528218-1:17528218) | "EFO_0004535" |
# |     1 | 1:16528218    | [1:15528218-1:17528218) | "EFO_0004535" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:15539259" | "EFO_0004518" | ["GCST90255485"] |
# | "Other measurement" | "1:15782677" | "EFO_0004518" | ["GCST90255485"] |
# | "Other measurement" | "1:15816768" | "EFO_0004518" | ["GCST90255485"] |
# +---------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "creatinine measurement" | "creatinine measurement" | 1:15539259    |
# | "creatinine measurement" | "creatinine measurement" | 1:15782677    |
# | "creatinine measurement" | "creatinine measurement" | 1:15816768    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 35
# 12
# 0
# 0
# trait_efo_category
# 0
# 47
# 0
# 0
# [Stage 144:===================================================>(984 + 2) / 1000]
# TSH
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 151:===================================================>(983 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:19841174    | [1:18841174-1:20841174) | "EFO_0004748" |
# |     2 | 1:22515032    | [1:21515032-1:23515032) | "EFO_0004748" |
# |     2 | 1:22515032    | [1:21515032-1:23515032) | "EFO_0004748" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:19964699" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "1:22115291" | "EFO_0000400" | ["GCST90255468"] |
# | "Other measurement" | "1:22355978" | "EFO_0004339" | ["GCST90255478"] |
# +---------------------+--------------+---------------+------------------+
#
# +---------------------+------------------------+---------------+
# | trait_efo_term      | trait_efo_category_otg | locus         |
# +---------------------+------------------------+---------------+
# | str                 | str                    | locus<GRCh37> |
# +---------------------+------------------------+---------------+
# | "body height"       | "body height"          | 1:19964699    |
# | "diabetes mellitus" | "diabetes mellitus"    | 1:22115291    |
# | "body height"       | "body height"          | 1:22355978    |
# +---------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 100
# 0
# 0
# trait_efo_category
# 0
# 100
# 0
# 0
# [Stage 155:==================================================> (975 + 2) / 1000]
# CEA
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 162:=================================================>  (959 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 2:109504287   | [2:108504287-2:110504287) | "EFO_0005760" |
# |     2 | 2:242709272   | [2:241709272-2:243199373) | "EFO_0005760" |
# |     2 | 2:242709272   | [2:241709272-2:243199373) | "EFO_0005760" |
# +-------+---------------+---------------------------+---------------+
#
# +---------------------+---------------+---------------+------------------+
# | trait_efo_category  | locus_otg     | trait_efo_otg | study_id_otg     |
# +---------------------+---------------+---------------+------------------+
# | str                 | str           | str           | array<str>       |
# +---------------------+---------------+---------------+------------------+
# | "Other measurement" | "2:109941182" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "2:241802259" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "2:241805851" | "EFO_0004339" | ["GCST90255478"] |
# +---------------------+---------------+---------------+------------------+
#
# +----------------+------------------------+---------------+
# | trait_efo_term | trait_efo_category_otg | locus         |
# +----------------+------------------------+---------------+
# | str            | str                    | locus<GRCh37> |
# +----------------+------------------------+---------------+
# | "body height"  | "body height"          | 2:109941182   |
# | "body height"  | "body height"          | 2:241802259   |
# | "body height"  | "body height"          | 2:241805851   |
# +----------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 16
# 0
# 0
# trait_efo_category
# 0
# 16
# 0
# 0
# [Stage 167:=================================================>  (958 + 2) / 1000]
# CREAT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 174:=================================================>  (957 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:10707812    | [1:9707812-1:11707812)  | "EFO_0004518" |
# |     1 | 1:10707812    | [1:9707812-1:11707812)  | "EFO_0004518" |
# |     1 | 1:10707812    | [1:9707812-1:11707812)  | "EFO_0004518" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:10702266" | "EFO_0004518" | ["GCST90255485"] |
# | "Other measurement" | "1:10709267" | "EFO_0004518" | ["GCST90255485"] |
# | "Other measurement" | "1:10722657" | "EFO_0004741" | ["GCST90255483"] |
# +---------------------+--------------+---------------+------------------+
#
# +-----------------------------------+-----------------------------------+
# | trait_efo_term                    | trait_efo_category_otg            |
# +-----------------------------------+-----------------------------------+
# | str                               | str                               |
# +-----------------------------------+-----------------------------------+
# | "creatinine measurement"          | "creatinine measurement"          |
# | "creatinine measurement"          | "creatinine measurement"          |
# | "blood urea nitrogen measurement" | "blood urea nitrogen measurement" |
# +-----------------------------------+-----------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:10702266    |
# | 1:10709267    |
# | 1:10722657    |
# +---------------+
# showing top 3 rows
# trait_efo
# 64
# 19
# 0
# 0
# trait_efo_category
# 0
# 83
# 0
# 0
# [Stage 178:=================================================>  (955 + 2) / 1000]
# ADIPO
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 185:==================================================> (966 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 3:52529266    | [3:51529266-3:53529266) | "EFO_0004502" |
# |     1 | 3:52529266    | [3:51529266-3:53529266) | "EFO_0004502" |
# |     1 | 3:52529266    | [3:51529266-3:53529266) | "EFO_0004502" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "3:51675348" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "3:52177700" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "3:52348364" | "EFO_0004535" | ["GCST90255484"] |
# +---------------------+--------------+---------------+------------------+
#
# +-----------------------------+-----------------------------+---------------+
# | trait_efo_term              | trait_efo_category_otg      | locus         |
# +-----------------------------+-----------------------------+---------------+
# | str                         | str                         | locus<GRCh37> |
# +-----------------------------+-----------------------------+---------------+
# | "body height"               | "body height"               | 3:51675348    |
# | "body height"               | "body height"               | 3:52177700    |
# | "serum albumin measurement" | "serum albumin measurement" | 3:52348364    |
# +-----------------------------+-----------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 13
# 0
# 0
# trait_efo_category
# 0
# 13
# 0
# 0
# [Stage 190:==================================================> (975 + 2) / 1000]
# URIC
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 197:=================================================>  (958 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:15914078    | [1:14914078-1:16914078) | "EFO_0004761" |
# |     1 | 1:15914078    | [1:14914078-1:16914078) | "EFO_0004761" |
# |     1 | 1:15914078    | [1:14914078-1:16914078) | "EFO_0004761" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------+--------------+---------------+
# | trait_efo_category           | locus_otg    | trait_efo_otg |
# +------------------------------+--------------+---------------+
# | str                          | str          | str           |
# +------------------------------+--------------+---------------+
# | "Cardiovascular measurement" | "1:15539259" | "EFO_0004518" |
# | "Cardiovascular measurement" | "1:15782677" | "EFO_0004518" |
# | "Cardiovascular measurement" | "1:15816768" | "EFO_0004518" |
# +------------------------------+--------------+---------------+
#
# +------------------+--------------------------+--------------------------+
# | study_id_otg     | trait_efo_term           | trait_efo_category_otg   |
# +------------------+--------------------------+--------------------------+
# | array<str>       | str                      | str                      |
# +------------------+--------------------------+--------------------------+
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# +------------------+--------------------------+--------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:15539259    |
# | 1:15782677    |
# | 1:15816768    |
# +---------------+
# showing top 3 rows
# trait_efo
# 38
# 62
# 0
# 0
# trait_efo_category
# 0
# 100
# 0
# 0
# [Stage 201:=================================================>  (959 + 2) / 1000]
# ALP
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# ...
# +-------+---------------+-------------------------+---------------+
#
# +--------------------+-------------+---------------+------------------+
# | trait_efo_category | locus_otg   | trait_efo_otg | study_id_otg     |
# +--------------------+-------------+---------------+------------------+
# | str                | str         | str           | array<str>       |
# +--------------------+-------------+---------------+------------------+
# | "Body measurement" | "1:1316674" | "EFO_0004339" | ["GCST90255478"] |
# | "Body measurement" | "1:2568425" | "EFO_0004340" | ["GCST90255480"] |
# | "Body measurement" | "1:2798205" | "EFO_0004339" | ["GCST90255478"] |
# +--------------------+-------------+---------------+------------------+
#
# +-------------------+------------------------+---------------+
# | trait_efo_term    | trait_efo_category_otg | locus         |
# +-------------------+------------------------+---------------+
# | str               | str                    | locus<GRCh37> |
# +-------------------+------------------------+---------------+
# | "body height"     | "body height"          | 1:1316674     |
# | "body mass index" | "body mass index"      | 1:2568425     |
# | "body height"     | "body height"          | 1:2798205     |
# +-------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 375
# 53
# 0
# 0
# trait_efo_category
# 0
# 428
# 0
# 0
# [Stage 368:===================================================>(984 + 2) / 1000]
# BMI
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 375:===================================================>(990 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     2 | 1:74992546    | [1:73992546-1:75992546) | "EFO_0004340" |
# |     2 | 1:74992546    | [1:73992546-1:75992546) | "EFO_0004340" |
# |     3 | 1:75790373    | [1:74790373-1:76790373) | "EFO_0004340" |
# +-------+---------------+-------------------------+---------------+
#
# +--------------------+--------------+---------------+------------------+
# | trait_efo_category | locus_otg    | trait_efo_otg | study_id_otg     |
# +--------------------+--------------+---------------+------------------+
# | str                | str          | str           | array<str>       |
# +--------------------+--------------+---------------+------------------+
# | "Body measurement" | "1:74968574" | "EFO_0004351" | ["GCST90278636"] |
# | "Body measurement" | "1:75006027" | "EFO_0004340" | ["GCST90255480"] |
# | "Body measurement" | "1:74968574" | "EFO_0004351" | ["GCST90278636"] |
# +--------------------+--------------+---------------+------------------+
#
# +----------------------+------------------------+---------------+
# | trait_efo_term       | trait_efo_category_otg | locus         |
# +----------------------+------------------------+---------------+
# | str                  | str                    | locus<GRCh37> |
# +----------------------+------------------------+---------------+
# | "resting heart rate" | "resting heart rate"   | 1:74968574    |
# | "body mass index"    | "body mass index"      | 1:75006027    |
# | "resting heart rate" | "resting heart rate"   | 1:74968574    |
# +----------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 107
# 61
# 0
# 0
# trait_efo_category
# 0
# 168
# 0
# 0
# [Stage 379:=================================================>  (957 + 2) / 1000]
# WAIST
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 386:===================================================>(993 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 1:177889025   | [1:176889025-1:178889025) | "EFO_0004342" |
# |     1 | 1:177889025   | [1:176889025-1:178889025) | "EFO_0004342" |
# |     1 | 1:177889025   | [1:176889025-1:178889025) | "EFO_0004342" |
# +-------+---------------+---------------------------+---------------+
#
# +--------------------+---------------+---------------+------------------+
# | trait_efo_category | locus_otg     | trait_efo_otg | study_id_otg     |
# +--------------------+---------------+---------------+------------------+
# | str                | str           | str           | array<str>       |
# +--------------------+---------------+---------------+------------------+
# | "Body measurement" | "1:177810571" | "EFO_0004340" | ["GCST90255413"] |
# | "Body measurement" | "1:177813039" | "EFO_0004340" | ["GCST90255480"] |
# | "Body measurement" | "1:177835040" | "EFO_0004340" | ["GCST90255413"] |
# +--------------------+---------------+---------------+------------------+
#
# +-------------------+------------------------+---------------+
# | trait_efo_term    | trait_efo_category_otg | locus         |
# +-------------------+------------------------+---------------+
# | str               | str                    | locus<GRCh37> |
# +-------------------+------------------------+---------------+
# | "body mass index" | "body mass index"      | 1:177810571   |
# | "body mass index" | "body mass index"      | 1:177813039   |
# | "body mass index" | "body mass index"      | 1:177835040   |
# +-------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 15
# 28
# 0
# 0
# trait_efo_category
# 0
# 43
# 0
# 0
# [Stage 390:===================================================>(988 + 2) / 1000]
# SMOKA_MOD
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 397:===================================================>(989 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 20:61993767   | [20:60993767-20:62993767) | "EFO_0004318" |
# |     1 | 20:61993767   | [20:60993767-20:62993767) | "EFO_0004318" |
# |     1 | 20:61993767   | [20:60993767-20:62993767) | "EFO_0004318" |
# +-------+---------------+---------------------------+---------------+
#
# +----------------------+---------------+---------------+------------------+
# | trait_efo_category   | locus_otg     | trait_efo_otg | study_id_otg     |
# +----------------------+---------------+---------------+------------------+
# | str                  | str           | str           | array<str>       |
# +----------------------+---------------+---------------+------------------+
# | "Biological process" | "20:61273960" | "EFO_0004468" | ["GCST90255482"] |
# | "Biological process" | "20:61992005" | "EFO_0004308" | ["GCST90255494"] |
# | "Biological process" | "20:62372706" | "EFO_0004339" | ["GCST90255478"] |
# +----------------------+---------------+---------------+------------------+
#
# +-----------------------+------------------------+---------------+
# | trait_efo_term        | trait_efo_category_otg | locus         |
# +-----------------------+------------------------+---------------+
# | str                   | str                    | locus<GRCh37> |
# +-----------------------+------------------------+---------------+
# | "glucose measurement" | "glucose measurement"  | 20:61273960   |
# | "leukocyte count"     | "leukocyte count"      | 20:61992005   |
# | "body height"         | "body height"          | 20:62372706   |
# +-----------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 1
# 0
# 0
# trait_efo_category
# 0
# 1
# 0
# 0
# [Stage 405:==================================================> (962 + 2) / 1000]
# ALCO_AMOUNT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 412:=================================================>  (960 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 3:38052725    | [3:37052725-3:39052725) | "EFO_0007878" |
# |     1 | 3:38052725    | [3:37052725-3:39052725) | "EFO_0007878" |
# |     1 | 3:38052725    | [3:37052725-3:39052725) | "EFO_0007878" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "3:38052613" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "3:38444489" | "EFO_0004518" | ["GCST90278624"] |
# | "Other measurement" | "3:38484175" | "EFO_0004518" | ["GCST90255485"] |
# +---------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "body height"            | "body height"            | 3:38052613    |
# | "creatinine measurement" | "creatinine measurement" | 3:38444489    |
# | "creatinine measurement" | "creatinine measurement" | 3:38484175    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 3
# 2
# 0
# 0
# trait_efo_category
# 0
# 5
# 0
# 0
# [Stage 417:=================================================>  (954 + 2) / 1000]
# COFFA
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 424:===================================================>(992 + 3) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 4:89020503    | [4:88020503-4:90020503) | "EFO_0006781" |
# |     1 | 4:89020503    | [4:88020503-4:90020503) | "EFO_0006781" |
# |     1 | 4:89020503    | [4:88020503-4:90020503) | "EFO_0006781" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "4:88022709" | "EFO_0004612" | ["GCST90255491"] |
# | "Other measurement" | "4:88039000" | "EFO_0004570" | ["GCST90255487"] |
# | "Other measurement" | "4:88040909" | "EFO_0004348" | ["GCST90255496"] |
# +---------------------+--------------+---------------+------------------+
#
# +----------------------------------------------------+
# | trait_efo_term                                     |
# +----------------------------------------------------+
# | str                                                |
# +----------------------------------------------------+
# | "high density lipoprotein cholesterol measurement" |
# | "bilirubin measurement"                            |
# | "hematocrit"                                       |
# +----------------------------------------------------+
#
# +----------------------------------------------------+---------------+
# | trait_efo_category_otg                             | locus         |
# +----------------------------------------------------+---------------+
# | str                                                | locus<GRCh37> |
# +----------------------------------------------------+---------------+
# | "high density lipoprotein cholesterol measurement" | 4:88022709    |
# | "bilirubin measurement"                            | 4:88039000    |
# | "hematocrit"                                       | 4:88040909    |
# +----------------------------------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 3
# 0
# 0
# trait_efo_category
# 0
# 3
# 0
# 0
# [Stage 429:===================================================>(998 + 2) / 1000]

# %%
## 500kb

# %%
trait_list = ["LDL", "TG", "HDL", "CHO", "FBS", "INSULIN","GOT", "GPT", "GGT", "BIL", "ALB","TSH", "CEA","CREAT","ADIPO","URIC", "ALP","HB", "HCT", "MCH", "MCHC", "MCV","RBC", "RDW", "WBC","PLT", "EOS", "SBP", "DBP", "WT",
              "HEIGHT", "BMI", "WAIST", "SMOKA_MOD", "ALCO_AMOUNT","COFFA"]
res = pd.DataFrame()
for i in range(len(trait_list)):
    trait = trait_list[i]
    print(trait)
    annotate_known_loci_500kb_EAS(trait)
# Out:
# LDL
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 436:===================================================>(981 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16505320    | [1:16005320-1:17005320) | "EFO_0004611" |
# |     1 | 1:16505320    | [1:16005320-1:17005320) | "EFO_0004611" |
# |     1 | 1:16505320    | [1:16005320-1:17005320) | "EFO_0004611" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:16184747" | "EFO_0003923" |
# | "Lipid or lipoprotein measurement" | "1:16184747" | "EFO_0003923" |
# | "Lipid or lipoprotein measurement" | "1:16364255" | "EFO_0004518" |
# +------------------------------------+--------------+---------------+
#
# +------------------+--------------------------+--------------------------+
# | study_id_otg     | trait_efo_term           | trait_efo_category_otg   |
# +------------------+--------------------------+--------------------------+
# | array<str>       | str                      | str                      |
# +------------------+--------------------------+--------------------------+
# | ["GCST90278620"] | "bone density"           | "bone density"           |
# | ["GCST90278621"] | "bone density"           | "bone density"           |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# +------------------+--------------------------+--------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:16184747    |
# | 1:16184747    |
# | 1:16364255    |
# +---------------+
# showing top 3 rows
# trait_efo
# 58
# 50
# 0
# 0
# trait_efo_category
# 0
# 108
# 0
# 0
# [Stage 440:==================================================> (976 + 2) / 1000]
# TG
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 447:==================================================> (964 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:63145439    | [1:62645439-1:63645439) | "EFO_0004530" |
# |     1 | 1:63145439    | [1:62645439-1:63645439) | "EFO_0004530" |
# |     1 | 1:63145439    | [1:62645439-1:63645439) | "EFO_0004530" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:62853713" | "EFO_0004530" |
# | "Lipid or lipoprotein measurement" | "1:62853713" | "EFO_0004530" |
# | "Lipid or lipoprotein measurement" | "1:63043657" | "EFO_0004530" |
# +------------------------------------+--------------+---------------+
#
# +------------------+----------------------------+----------------------------+
# | study_id_otg     | trait_efo_term             | trait_efo_category_otg     |
# +------------------+----------------------------+----------------------------+
# | array<str>       | str                        | str                        |
# +------------------+----------------------------+----------------------------+
# | ["GCST90255493"] | "triglyceride measurement" | "triglyceride measurement" |
# | ["GCST90255426"] | "triglyceride measurement" | "triglyceride measurement" |
# | ["GCST90255493"] | "triglyceride measurement" | "triglyceride measurement" |
# +------------------+----------------------------+----------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:62853713    |
# | 1:62853713    |
# | 1:63043657    |
# +---------------+
# showing top 3 rows
# trait_efo
# 52
# 28
# 0
# 0
# trait_efo_category
# 0
# 80
# 0
# 0
# [Stage 451:===================================================>(993 + 2) / 1000]
# HDL
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 458:==================================================> (972 + 3) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:40064961    | [1:39564961-1:40564961) | "EFO_0004612" |
# |     1 | 1:40064961    | [1:39564961-1:40564961) | "EFO_0004612" |
# |     1 | 1:40064961    | [1:39564961-1:40564961) | "EFO_0004612" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:39976059" | "EFO_0000400" |
# | "Lipid or lipoprotein measurement" | "1:39976076" | "EFO_0004541" |
# | "Lipid or lipoprotein measurement" | "1:39980885" | "EFO_0004530" |
# +------------------------------------+--------------+---------------+
#
# +------------------+----------------------------+----------------------------+
# | study_id_otg     | trait_efo_term             | trait_efo_category_otg     |
# +------------------+----------------------------+----------------------------+
# | array<str>       | str                        | str                        |
# +------------------+----------------------------+----------------------------+
# | ["GCST90255468"] | "diabetes mellitus"        | "diabetes mellitus"        |
# | ["GCST90278632"] | "HbA1c measurement"        | "HbA1c measurement"        |
# | ["GCST90278645"] | "triglyceride measurement" | "triglyceride measurement" |
# +------------------+----------------------------+----------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:39976059    |
# | 1:39976076    |
# | 1:39980885    |
# +---------------+
# showing top 3 rows
# trait_efo
# 52
# 10
# 0
# 0
# trait_efo_category
# 0
# 62
# 0
# 0
# [Stage 462:==================================================> (978 + 2) / 1000]
# CHO
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 469:==================================================> (963 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:25829988    | [1:25329988-1:26329988) | "EFO_0004574" |
# |     1 | 1:25829988    | [1:25329988-1:26329988) | "EFO_0004574" |
# |     1 | 1:25829988    | [1:25329988-1:26329988) | "EFO_0004574" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------------+--------------+---------------+
# | trait_efo_category                 | locus_otg    | trait_efo_otg |
# +------------------------------------+--------------+---------------+
# | str                                | str          | str           |
# +------------------------------------+--------------+---------------+
# | "Lipid or lipoprotein measurement" | "1:25607316" | "EFO_0004541" |
# | "Lipid or lipoprotein measurement" | "1:25611035" | "EFO_0004541" |
# | "Lipid or lipoprotein measurement" | "1:25677844" | "EFO_0004541" |
# +------------------------------------+--------------+---------------+
#
# +------------------+---------------------+------------------------+
# | study_id_otg     | trait_efo_term      | trait_efo_category_otg |
# +------------------+---------------------+------------------------+
# | array<str>       | str                 | str                    |
# +------------------+---------------------+------------------------+
# | ["GCST90255414"] | "HbA1c measurement" | "HbA1c measurement"    |
# | ["GCST90255481"] | "HbA1c measurement" | "HbA1c measurement"    |
# | ["GCST90278632"] | "HbA1c measurement" | "HbA1c measurement"    |
# +------------------+---------------------+------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:25607316    |
# | 1:25611035    |
# | 1:25677844    |
# +---------------+
# showing top 3 rows
# trait_efo
# 78
# 63
# 0
# 0
# trait_efo_category
# 0
# 141
# 0
# 0
# [Stage 473:==================================================> (963 + 2) / 1000]
# FBS
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 480:===================================================>(985 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:43453188    | [1:42953188-1:43953188) | "EFO_0004468" |
# |     1 | 1:43453188    | [1:42953188-1:43953188) | "EFO_0004468" |
# |     1 | 1:43453188    | [1:42953188-1:43953188) | "EFO_0004468" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:43455283" | "EFO_0004465" | ["GCST90278628"] |
# | "Other measurement" | "1:43805737" | "EFO_0004308" | ["GCST90278647"] |
# | "Other measurement" | "1:43884714" | "EFO_0004309" | ["GCST90255498"] |
# +---------------------+--------------+---------------+------------------+
#
# +-------------------------------------+-------------------------------------+
# | trait_efo_term                      | trait_efo_category_otg              |
# +-------------------------------------+-------------------------------------+
# | str                                 | str                                 |
# +-------------------------------------+-------------------------------------+
# | "fasting blood glucose measurement" | "fasting blood glucose measurement" |
# | "leukocyte count"                   | "leukocyte count"                   |
# | "platelet count"                    | "platelet count"                    |
# +-------------------------------------+-------------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:43455283    |
# | 1:43805737    |
# | 1:43884714    |
# +---------------+
# showing top 3 rows
# trait_efo
# 47
# 40
# 0
# 0
# trait_efo_category
# 0
# 87
# 0
# 0
# [Stage 484:===================================================>(981 + 2) / 1000]
# INSULIN
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 491:==================================================> (972 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 2:27730940    | [2:27230940-2:28230940) | "EFO_0004467" |
# |     1 | 2:27730940    | [2:27230940-2:28230940) | "EFO_0004467" |
# |     1 | 2:27730940    | [2:27230940-2:28230940) | "EFO_0004467" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "2:27333445" | "EFO_0004530" | ["GCST90255426"] |
# | "Other measurement" | "2:27341204" | "EFO_0004532" | ["GCST90255490"] |
# | "Other measurement" | "2:27341204" | "EFO_0004530" | ["GCST90255493"] |
# +---------------------+--------------+---------------+------------------+
#
# +------------------------------------------------+
# | trait_efo_term                                 |
# +------------------------------------------------+
# | str                                            |
# +------------------------------------------------+
# | "triglyceride measurement"                     |
# | "serum gamma-glutamyl transferase measurement" |
# | "triglyceride measurement"                     |
# +------------------------------------------------+
#
# +------------------------------------------------+---------------+
# | trait_efo_category_otg                         | locus         |
# +------------------------------------------------+---------------+
# | str                                            | locus<GRCh37> |
# +------------------------------------------------+---------------+
# | "triglyceride measurement"                     | 2:27333445    |
# | "serum gamma-glutamyl transferase measurement" | 2:27341204    |
# | "triglyceride measurement"                     | 2:27341204    |
# +------------------------------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 6
# 0
# 0
# trait_efo_category
# 0
# 6
# 0
# 0
# [Stage 496:==================================================> (970 + 2) / 1000]
# GOT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 503:===================================================>(983 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16516585    | [1:16016585-1:17016585) | "EFO_0004736" |
# |     1 | 1:16516585    | [1:16016585-1:17016585) | "EFO_0004736" |
# |     1 | 1:16516585    | [1:16016585-1:17016585) | "EFO_0004736" |
# +-------+---------------+-------------------------+---------------+
#
# +----------------------------+--------------+---------------+------------------+
# | trait_efo_category         | locus_otg    | trait_efo_otg | study_id_otg     |
# +----------------------------+--------------+---------------+------------------+
# | str                        | str          | str           | array<str>       |
# +----------------------------+--------------+---------------+------------------+
# | "Liver enzyme measurement" | "1:16184747" | "EFO_0003923" | ["GCST90278620"] |
# | "Liver enzyme measurement" | "1:16184747" | "EFO_0003923" | ["GCST90278621"] |
# | "Liver enzyme measurement" | "1:16364255" | "EFO_0004518" | ["GCST90255485"] |
# +----------------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "bone density"           | "bone density"           | 1:16184747    |
# | "bone density"           | "bone density"           | 1:16184747    |
# | "creatinine measurement" | "creatinine measurement" | 1:16364255    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 39
# 31
# 0
# 0
# trait_efo_category
# 0
# 70
# 0
# 0
# [Stage 507:==================================================> (969 + 2) / 1000]
# GPT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 514:==================================================> (979 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:31886498    | [1:31386498-1:32386498) | "EFO_0004735" |
# |     1 | 1:31886498    | [1:31386498-1:32386498) | "EFO_0004735" |
# |     1 | 1:31886498    | [1:31386498-1:32386498) | "EFO_0004735" |
# +-------+---------------+-------------------------+---------------+
#
# +----------------------------+--------------+---------------+------------------+
# | trait_efo_category         | locus_otg    | trait_efo_otg | study_id_otg     |
# +----------------------------+--------------+---------------+------------------+
# | str                        | str          | str           | array<str>       |
# +----------------------------+--------------+---------------+------------------+
# | "Liver enzyme measurement" | "1:31707354" | "EFO_0004518" | ["GCST90255485"] |
# | "Liver enzyme measurement" | "1:31872750" | "EFO_0004736" | ["GCST90255486"] |
# | "Liver enzyme measurement" | "1:31881152" | "EFO_0004735" | ["GCST90255488"] |
# +----------------------------+--------------+---------------+------------------+
#
# +----------------------------------------------+
# | trait_efo_term                               |
# +----------------------------------------------+
# | str                                          |
# +----------------------------------------------+
# | "creatinine measurement"                     |
# | "aspartate aminotransferase measurement"     |
# | "serum alanine aminotransferase measurement" |
# +----------------------------------------------+
#
# +----------------------------------------------+---------------+
# | trait_efo_category_otg                       | locus         |
# +----------------------------------------------+---------------+
# | str                                          | locus<GRCh37> |
# +----------------------------------------------+---------------+
# | "creatinine measurement"                     | 1:31707354    |
# | "aspartate aminotransferase measurement"     | 1:31872750    |
# | "serum alanine aminotransferase measurement" | 1:31881152    |
# +----------------------------------------------+---------------+
# showing top 3 rows
# trait_efo
# 38
# 30
# 0
# 0
# trait_efo_category
# 0
# 68
# 0
# 0
# [Stage 518:===================================================>(995 + 2) / 1000]
# GGT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 525:==================================================> (979 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16505320    | [1:16005320-1:17005320) | "EFO_0004532" |
# |     1 | 1:16505320    | [1:16005320-1:17005320) | "EFO_0004532" |
# |     1 | 1:16505320    | [1:16005320-1:17005320) | "EFO_0004532" |
# +-------+---------------+-------------------------+---------------+
#
# +----------------------------+--------------+---------------+------------------+
# | trait_efo_category         | locus_otg    | trait_efo_otg | study_id_otg     |
# +----------------------------+--------------+---------------+------------------+
# | str                        | str          | str           | array<str>       |
# +----------------------------+--------------+---------------+------------------+
# | "Liver enzyme measurement" | "1:16184747" | "EFO_0003923" | ["GCST90278620"] |
# | "Liver enzyme measurement" | "1:16184747" | "EFO_0003923" | ["GCST90278621"] |
# | "Liver enzyme measurement" | "1:16364255" | "EFO_0004518" | ["GCST90255485"] |
# +----------------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "bone density"           | "bone density"           | 1:16184747    |
# | "bone density"           | "bone density"           | 1:16184747    |
# | "creatinine measurement" | "creatinine measurement" | 1:16364255    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 77
# 27
# 0
# 0
# trait_efo_category
# 0
# 104
# 0
# 0
# [Stage 529:=================================================>  (960 + 2) / 1000]
# BIL
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 536:===================================================>(989 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 1:156245606   | [1:155745606-1:156745606) | "EFO_0004570" |
# |     1 | 1:156245606   | [1:155745606-1:156745606) | "EFO_0004570" |
# |     1 | 1:156245606   | [1:155745606-1:156745606) | "EFO_0004570" |
# +-------+---------------+---------------------------+---------------+
#
# +---------------------+---------------+---------------+------------------+
# | trait_efo_category  | locus_otg     | trait_efo_otg | study_id_otg     |
# +---------------------+---------------+---------------+------------------+
# | str                 | str           | str           | array<str>       |
# +---------------------+---------------+---------------+------------------+
# | "Other measurement" | "1:156045662" | "EFO_0004741" | ["GCST90255483"] |
# | "Other measurement" | "1:156045662" | "EFO_0000178" | ["GCST90255470"] |
# | "Other measurement" | "1:156095359" | "EFO_0004509" | ["GCST90255497"] |
# +---------------------+---------------+---------------+------------------+
#
# +-----------------------------------+-----------------------------------+
# | trait_efo_term                    | trait_efo_category_otg            |
# +-----------------------------------+-----------------------------------+
# | str                               | str                               |
# +-----------------------------------+-----------------------------------+
# | "blood urea nitrogen measurement" | "blood urea nitrogen measurement" |
# | "gastric carcinoma"               | "gastric carcinoma"               |
# | "hemoglobin measurement"          | "hemoglobin measurement"          |
# +-----------------------------------+-----------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:156045662   |
# | 1:156045662   |
# | 1:156095359   |
# +---------------+
# showing top 3 rows
# trait_efo
# 24
# 21
# 0
# 0
# trait_efo_category
# 0
# 45
# 0
# 0
# [Stage 540:==================================================> (979 + 2) / 1000]
# ALB
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 547:==================================================> (964 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:16528218    | [1:16028218-1:17028218) | "EFO_0004535" |
# |     1 | 1:16528218    | [1:16028218-1:17028218) | "EFO_0004535" |
# |     1 | 1:16528218    | [1:16028218-1:17028218) | "EFO_0004535" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:16184747" | "EFO_0003923" | ["GCST90278620"] |
# | "Other measurement" | "1:16184747" | "EFO_0003923" | ["GCST90278621"] |
# | "Other measurement" | "1:16364255" | "EFO_0004518" | ["GCST90255485"] |
# +---------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "bone density"           | "bone density"           | 1:16184747    |
# | "bone density"           | "bone density"           | 1:16184747    |
# | "creatinine measurement" | "creatinine measurement" | 1:16364255    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 35
# 12
# 0
# 0
# trait_efo_category
# 0
# 47
# 0
# 0
# [Stage 551:===================================================>(993 + 2) / 1000]
# TSH
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 558:==================================================> (964 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:19841174    | [1:19341174-1:20341174) | "EFO_0004748" |
# |     2 | 1:22515032    | [1:22015032-1:23015032) | "EFO_0004748" |
# |     2 | 1:22515032    | [1:22015032-1:23015032) | "EFO_0004748" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:19964699" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "1:22115291" | "EFO_0000400" | ["GCST90255468"] |
# | "Other measurement" | "1:22355978" | "EFO_0004339" | ["GCST90255478"] |
# +---------------------+--------------+---------------+------------------+
#
# +---------------------+------------------------+---------------+
# | trait_efo_term      | trait_efo_category_otg | locus         |
# +---------------------+------------------------+---------------+
# | str                 | str                    | locus<GRCh37> |
# +---------------------+------------------------+---------------+
# | "body height"       | "body height"          | 1:19964699    |
# | "diabetes mellitus" | "diabetes mellitus"    | 1:22115291    |
# | "body height"       | "body height"          | 1:22355978    |
# +---------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 100
# 0
# 0
# trait_efo_category
# 0
# 100
# 0
# 0
# [Stage 562:===================================================>(991 + 2) / 1000]
# CEA
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 569:=================================================>  (957 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 2:109504287   | [2:109004287-2:110004287) | "EFO_0005760" |
# |     2 | 2:242709272   | [2:242209272-2:243199373) | "EFO_0005760" |
# |     2 | 2:242709272   | [2:242209272-2:243199373) | "EFO_0005760" |
# +-------+---------------+---------------------------+---------------+
#
# +---------------------+---------------+---------------+------------------+
# | trait_efo_category  | locus_otg     | trait_efo_otg | study_id_otg     |
# +---------------------+---------------+---------------+------------------+
# | str                 | str           | str           | array<str>       |
# +---------------------+---------------+---------------+------------------+
# | "Other measurement" | "2:109941182" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "2:242237902" | "EFO_0004535" | ["GCST90278616"] |
# | "Other measurement" | "2:242288798" | "EFO_0004339" | ["GCST90255411"] |
# +---------------------+---------------+---------------+------------------+
#
# +-----------------------------+-----------------------------+---------------+
# | trait_efo_term              | trait_efo_category_otg      | locus         |
# +-----------------------------+-----------------------------+---------------+
# | str                         | str                         | locus<GRCh37> |
# +-----------------------------+-----------------------------+---------------+
# | "body height"               | "body height"               | 2:109941182   |
# | "serum albumin measurement" | "serum albumin measurement" | 2:242237902   |
# | "body height"               | "body height"               | 2:242288798   |
# +-----------------------------+-----------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 16
# 0
# 0
# trait_efo_category
# 0
# 16
# 0
# 0
# [Stage 574:==================================================> (976 + 2) / 1000]
# CREAT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 581:===================================================>(981 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:10707812    | [1:10207812-1:11207812) | "EFO_0004518" |
# |     1 | 1:10707812    | [1:10207812-1:11207812) | "EFO_0004518" |
# |     1 | 1:10707812    | [1:10207812-1:11207812) | "EFO_0004518" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:10702266" | "EFO_0004518" | ["GCST90255485"] |
# | "Other measurement" | "1:10709267" | "EFO_0004518" | ["GCST90255485"] |
# | "Other measurement" | "1:10722657" | "EFO_0004741" | ["GCST90255483"] |
# +---------------------+--------------+---------------+------------------+
#
# +-----------------------------------+-----------------------------------+
# | trait_efo_term                    | trait_efo_category_otg            |
# +-----------------------------------+-----------------------------------+
# | str                               | str                               |
# +-----------------------------------+-----------------------------------+
# | "creatinine measurement"          | "creatinine measurement"          |
# | "creatinine measurement"          | "creatinine measurement"          |
# | "blood urea nitrogen measurement" | "blood urea nitrogen measurement" |
# +-----------------------------------+-----------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:10702266    |
# | 1:10709267    |
# | 1:10722657    |
# +---------------+
# showing top 3 rows
# trait_efo
# 63
# 20
# 0
# 0
# trait_efo_category
# 0
# 83
# 0
# 0
# [Stage 585:==================================================> (970 + 2) / 1000]
# ADIPO
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 592:===================================================>(998 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 3:52529266    | [3:52029266-3:53029266) | "EFO_0004502" |
# |     1 | 3:52529266    | [3:52029266-3:53029266) | "EFO_0004502" |
# |     1 | 3:52529266    | [3:52029266-3:53029266) | "EFO_0004502" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "3:52177700" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "3:52348364" | "EFO_0004535" | ["GCST90255484"] |
# | "Other measurement" | "3:52584787" | "EFO_0004339" | ["GCST90255478"] |
# +---------------------+--------------+---------------+------------------+
#
# +-----------------------------+-----------------------------+---------------+
# | trait_efo_term              | trait_efo_category_otg      | locus         |
# +-----------------------------+-----------------------------+---------------+
# | str                         | str                         | locus<GRCh37> |
# +-----------------------------+-----------------------------+---------------+
# | "body height"               | "body height"               | 3:52177700    |
# | "serum albumin measurement" | "serum albumin measurement" | 3:52348364    |
# | "body height"               | "body height"               | 3:52584787    |
# +-----------------------------+-----------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 13
# 0
# 0
# trait_efo_category
# 0
# 13
# 0
# 0
# [Stage 597:===================================================>(983 + 2) / 1000]
# URIC
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 604:==================================================> (973 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:15914078    | [1:15414078-1:16414078) | "EFO_0004761" |
# |     1 | 1:15914078    | [1:15414078-1:16414078) | "EFO_0004761" |
# |     1 | 1:15914078    | [1:15414078-1:16414078) | "EFO_0004761" |
# +-------+---------------+-------------------------+---------------+
#
# +------------------------------+--------------+---------------+
# | trait_efo_category           | locus_otg    | trait_efo_otg |
# +------------------------------+--------------+---------------+
# | str                          | str          | str           |
# +------------------------------+--------------+---------------+
# | "Cardiovascular measurement" | "1:15539259" | "EFO_0004518" |
# | "Cardiovascular measurement" | "1:15782677" | "EFO_0004518" |
# | "Cardiovascular measurement" | "1:15816768" | "EFO_0004518" |
# +------------------------------+--------------+---------------+
#
# +------------------+--------------------------+--------------------------+
# | study_id_otg     | trait_efo_term           | trait_efo_category_otg   |
# +------------------+--------------------------+--------------------------+
# | array<str>       | str                      | str                      |
# +------------------+--------------------------+--------------------------+
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# | ["GCST90255485"] | "creatinine measurement" | "creatinine measurement" |
# +------------------+--------------------------+--------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:15539259    |
# | 1:15782677    |
# | 1:15816768    |
# +---------------+
# showing top 3 rows
# trait_efo
# 37
# 63
# 0
# 0
# trait_efo_category
# 0
# 100
# 0
# 0
# [Stage 608:==================================================> (975 + 2) / 1000]
# ALP
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# ...
# |     2 | 1:3417131     | [1:2917131-1:3917131)   | "EFO_0004339" |
# |     2 | 1:3417131     | [1:2917131-1:3917131)   | "EFO_0004339" |
# +-------+---------------+-------------------------+---------------+
#
# +--------------------+-------------+---------------+------------------+
# | trait_efo_category | locus_otg   | trait_efo_otg | study_id_otg     |
# +--------------------+-------------+---------------+------------------+
# | str                | str         | str           | array<str>       |
# +--------------------+-------------+---------------+------------------+
# | "Body measurement" | "1:1316674" | "EFO_0004339" | ["GCST90255478"] |
# | "Body measurement" | "1:3051621" | "EFO_0004339" | ["GCST90255478"] |
# | "Body measurement" | "1:3099194" | "EFO_0004305" | ["GCST90255495"] |
# +--------------------+-------------+---------------+------------------+
#
# +---------------------+------------------------+---------------+
# | trait_efo_term      | trait_efo_category_otg | locus         |
# +---------------------+------------------------+---------------+
# | str                 | str                    | locus<GRCh37> |
# +---------------------+------------------------+---------------+
# | "body height"       | "body height"          | 1:1316674     |
# | "body height"       | "body height"          | 1:3051621     |
# | "erythrocyte count" | "erythrocyte count"    | 1:3099194     |
# +---------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 358
# 70
# 0
# 0
# trait_efo_category
# 0
# 428
# 0
# 0
# [Stage 777:===================================================>(983 + 2) / 1000]
# BMI
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 784:===================================================>(998 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     2 | 1:74992546    | [1:74492546-1:75492546)   | "EFO_0004340" |
# |     2 | 1:74992546    | [1:74492546-1:75492546)   | "EFO_0004340" |
# |     4 | 1:107886546   | [1:107386546-1:108386546) | "EFO_0004340" |
# +-------+---------------+---------------------------+---------------+
#
# +--------------------+---------------+---------------+------------------+
# | trait_efo_category | locus_otg     | trait_efo_otg | study_id_otg     |
# +--------------------+---------------+---------------+------------------+
# | str                | str           | str           | array<str>       |
# +--------------------+---------------+---------------+------------------+
# | "Body measurement" | "1:74968574"  | "EFO_0004351" | ["GCST90278636"] |
# | "Body measurement" | "1:75006027"  | "EFO_0004340" | ["GCST90255480"] |
# | "Body measurement" | "1:107907401" | "EFO_0004340" | ["GCST90255480"] |
# +--------------------+---------------+---------------+------------------+
#
# +----------------------+------------------------+---------------+
# | trait_efo_term       | trait_efo_category_otg | locus         |
# +----------------------+------------------------+---------------+
# | str                  | str                    | locus<GRCh37> |
# +----------------------+------------------------+---------------+
# | "resting heart rate" | "resting heart rate"   | 1:74968574    |
# | "body mass index"    | "body mass index"      | 1:75006027    |
# | "body mass index"    | "body mass index"      | 1:107907401   |
# +----------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 96
# 72
# 0
# 0
# trait_efo_category
# 0
# 168
# 0
# 0
# [Stage 788:===================================================>(988 + 2) / 1000]
# WAIST
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 795:==================================================> (977 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 1:177889025   | [1:177389025-1:178389025) | "EFO_0004342" |
# |     1 | 1:177889025   | [1:177389025-1:178389025) | "EFO_0004342" |
# |     1 | 1:177889025   | [1:177389025-1:178389025) | "EFO_0004342" |
# +-------+---------------+---------------------------+---------------+
#
# +--------------------+---------------+---------------+------------------+
# | trait_efo_category | locus_otg     | trait_efo_otg | study_id_otg     |
# +--------------------+---------------+---------------+------------------+
# | str                | str           | str           | array<str>       |
# +--------------------+---------------+---------------+------------------+
# | "Body measurement" | "1:177810571" | "EFO_0004340" | ["GCST90255413"] |
# | "Body measurement" | "1:177813039" | "EFO_0004340" | ["GCST90255480"] |
# | "Body measurement" | "1:177835040" | "EFO_0004340" | ["GCST90255413"] |
# +--------------------+---------------+---------------+------------------+
#
# +-------------------+------------------------+---------------+
# | trait_efo_term    | trait_efo_category_otg | locus         |
# +-------------------+------------------------+---------------+
# | str               | str                    | locus<GRCh37> |
# +-------------------+------------------------+---------------+
# | "body mass index" | "body mass index"      | 1:177810571   |
# | "body mass index" | "body mass index"      | 1:177813039   |
# | "body mass index" | "body mass index"      | 1:177835040   |
# +-------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 15
# 28
# 0
# 0
# trait_efo_category
# 0
# 43
# 0
# 0
# [Stage 800:==================================================> (970 + 2) / 1000]
# SMOKA_MOD
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 813:========================================>           (777 + 2) / 1000]
# +-------+---------------+---------------------------+---------------+
# |   idx | lead_locus    | region                    | trait_efo     |
# +-------+---------------+---------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>>   | str           |
# +-------+---------------+---------------------------+---------------+
# |     1 | 20:61993767   | [20:61493767-20:62493767) | "EFO_0004318" |
# |     1 | 20:61993767   | [20:61493767-20:62493767) | "EFO_0004318" |
# |     1 | 20:61993767   | [20:61493767-20:62493767) | "EFO_0004318" |
# +-------+---------------+---------------------------+---------------+
#
# +----------------------+---------------+---------------+------------------+
# | trait_efo_category   | locus_otg     | trait_efo_otg | study_id_otg     |
# +----------------------+---------------+---------------+------------------+
# | str                  | str           | str           | array<str>       |
# +----------------------+---------------+---------------+------------------+
# | "Biological process" | "20:61992005" | "EFO_0004308" | ["GCST90255494"] |
# | "Biological process" | "20:62372706" | "EFO_0004339" | ["GCST90255478"] |
# | "Biological process" | "20:62435465" | "EFO_0004348" | ["GCST90255496"] |
# +----------------------+---------------+---------------+------------------+
#
# +-------------------+------------------------+---------------+
# | trait_efo_term    | trait_efo_category_otg | locus         |
# +-------------------+------------------------+---------------+
# | str               | str                    | locus<GRCh37> |
# +-------------------+------------------------+---------------+
# | "leukocyte count" | "leukocyte count"      | 20:61992005   |
# | "body height"     | "body height"          | 20:62372706   |
# | "hematocrit"      | "hematocrit"           | 20:62435465   |
# +-------------------+------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 1
# 0
# 0
# trait_efo_category
# 0
# 1
# 0
# 0
# [Stage 815:===================================================>(995 + 2) / 1000]
# ALCO_AMOUNT
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 822:=================================================>  (960 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 3:38052725    | [3:37552725-3:38552725) | "EFO_0007878" |
# |     1 | 3:38052725    | [3:37552725-3:38552725) | "EFO_0007878" |
# |     1 | 3:38052725    | [3:37552725-3:38552725) | "EFO_0007878" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "3:38052613" | "EFO_0004339" | ["GCST90255478"] |
# | "Other measurement" | "3:38444489" | "EFO_0004518" | ["GCST90278624"] |
# | "Other measurement" | "3:38484175" | "EFO_0004518" | ["GCST90255485"] |
# +---------------------+--------------+---------------+------------------+
#
# +--------------------------+--------------------------+---------------+
# | trait_efo_term           | trait_efo_category_otg   | locus         |
# +--------------------------+--------------------------+---------------+
# | str                      | str                      | locus<GRCh37> |
# +--------------------------+--------------------------+---------------+
# | "body height"            | "body height"            | 3:38052613    |
# | "creatinine measurement" | "creatinine measurement" | 3:38444489    |
# | "creatinine measurement" | "creatinine measurement" | 3:38484175    |
# +--------------------------+--------------------------+---------------+
# showing top 3 rows
# trait_efo
# 3
# 2
# 0
# 0
# trait_efo_category
# 0
# 5
# 0
# 0
# [Stage 828:==================================================> (973 + 2) / 1000]
# COFFA
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 835:=================================================>  (956 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 4:89020503    | [4:88520503-4:89520503) | "EFO_0006781" |
# |     1 | 4:89020503    | [4:88520503-4:89520503) | "EFO_0006781" |
# |     1 | 4:89020503    | [4:88520503-4:89520503) | "EFO_0006781" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "4:88692427" | "EFO_0004735" | ["GCST90255488"] |
# | "Other measurement" | "4:88768860" | "EFO_0003923" | ["GCST90278620"] |
# | "Other measurement" | "4:88768860" | "EFO_0003923" | ["GCST90278621"] |
# +---------------------+--------------+---------------+------------------+
#
# +----------------------------------------------+
# | trait_efo_term                               |
# +----------------------------------------------+
# | str                                          |
# +----------------------------------------------+
# | "serum alanine aminotransferase measurement" |
# | "bone density"                               |
# | "bone density"                               |
# +----------------------------------------------+
#
# +----------------------------------------------+---------------+
# | trait_efo_category_otg                       | locus         |
# +----------------------------------------------+---------------+
# | str                                          | locus<GRCh37> |
# +----------------------------------------------+---------------+
# | "serum alanine aminotransferase measurement" | 4:88692427    |
# | "bone density"                               | 4:88768860    |
# | "bone density"                               | 4:88768860    |
# +----------------------------------------------+---------------+
# showing top 3 rows
# trait_efo
# 0
# 3
# 0
# 0
# trait_efo_category
# 0
# 3
# 0
# 0
# [Stage 841:===================================================>(997 + 2) / 1000]

# %%
# 10/05/2024
# After correcting EFO_ID for FBS

# %%
trait_list = ["FBS"]
res = pd.DataFrame()
for i in range(len(trait_list)):
    trait = trait_list[i]
    print(trait)
    annotate_known_loci_500kb_EAS(trait)
# Out:
# Initializing Hail with default parameters...
# FBS
# 24/10/06 00:25:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Running on Apache Spark version 3.3.4
# SparkUI available at http://holy7c04105.rc.fas.harvard.edu:4042
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.130-bea04d9c79b5
# LOGGING: writing to /n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/hail-20241006-0025-0.2.130-bea04d9c79b5.log
# 2024-10-06 00:25:25.952 Hail: INFO: Reading table to impute column types
# 2024-10-06 00:25:27.198 Hail: INFO: Finished type imputation
#   Loading field 'locus' as type str (imputed)
#   Loading field 'trait_efo' as type str (imputed)
#   Loading field 'study_id' as type str (imputed)
#   Loading field 'trait_efo_term' as type str (imputed)
#   Loading field 'trait_efo_category' as type str (imputed)
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# 2024-10-06 00:25:30.841 Hail: INFO: Reading table to impute column types
# 2024-10-06 00:25:41.574 Hail: INFO: Finished type imputation=> (973 + 2) / 1000]
#   Loading field 'idx' as type int32 (imputed)
#   Loading field 'lead_locus' as type str (imputed)
#   Loading field 'region' as type str (imputed)
#   Loading field 'trait_efo' as type str (imputed)
#   Loading field 'trait_efo_category' as type str (imputed)
#   Loading field 'locus' as type str (imputed)
#   Loading field 'trait_efo_otg' as type str (imputed)
#   Loading field 'study_id' as type str (imputed)
#   Loading field 'trait_efo_term' as type str (imputed)
#   Loading field 'trait_efo_category_otg' as type str (imputed)
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:43453188    | [1:42953188-1:43953188) | "EFO_0004465" |
# |     1 | 1:43453188    | [1:42953188-1:43953188) | "EFO_0004465" |
# |     1 | 1:43453188    | [1:42953188-1:43953188) | "EFO_0004465" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:43455283" | "EFO_0004465" | ["GCST90278628"] |
# | "Other measurement" | "1:43805737" | "EFO_0004308" | ["GCST90278647"] |
# | "Other measurement" | "1:43884714" | "EFO_0004309" | ["GCST90255498"] |
# +---------------------+--------------+---------------+------------------+
#
# +-------------------------------------+-------------------------------------+
# | trait_efo_term                      | trait_efo_category_otg              |
# +-------------------------------------+-------------------------------------+
# | str                                 | str                                 |
# +-------------------------------------+-------------------------------------+
# | "fasting blood glucose measurement" | "fasting blood glucose measurement" |
# | "leukocyte count"                   | "leukocyte count"                   |
# | "platelet count"                    | "platelet count"                    |
# +-------------------------------------+-------------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:43455283    |
# | 1:43805737    |
# | 1:43884714    |
# +---------------+
# showing top 3 rows
# trait_efo
# 44
# 43
# 0
# 0
# trait_efo_category
# 0
# 87
# 0
# 0
# 2024-10-06 00:25:53.038 Hail: INFO: merging 1001 files totalling 232.1K... 1000]
# 2024-10-06 00:25:53.179 Hail: INFO: while writing:
#     /n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_otg/known_kcps2_loci_FBS_500kb_EAS.tsv
#   merge time: 138.290ms
# 2024-10-06 00:26:36.188 Hail: INFO: Reading table to impute column types
# 2024-10-06 00:26:36.650 Hail: INFO: Finished type imputation
#   Loading field 'locus' as type str (imputed)
#   Loading field 'trait_efo' as type str (imputed)
#   Loading field 'study_id' as type str (imputed)
#   Loading field 'trait_efo_term' as type str (imputed)
#   Loading field 'trait_efo_category' as type str (imputed)
# 2024-10-06 00:26:38.823 Hail: INFO: Reading table to impute column types
# 2024-10-06 00:26:46.464 Hail: INFO: Finished type imputation
#   Loading field 'idx' as type int32 (imputed)
#   Loading field 'lead_locus' as type str (imputed)
#   Loading field 'region' as type str (imputed)
#   Loading field 'trait_efo' as type str (imputed)
#   Loading field 'trait_efo_category' as type str (imputed)
#   Loading field 'locus' as type str (imputed)
#   Loading field 'trait_efo_otg' as type str (imputed)
#   Loading field 'study_id' as type str (imputed)
#   Loading field 'trait_efo_term' as type str (imputed)
#   Loading field 'trait_efo_category_otg' as type str (imputed)
# 2024-10-06 00:26:55.327 Hail: INFO: merging 1001 files totalling 324.9K...
# 2024-10-06 00:26:55.488 Hail: INFO: while writing:
#     /n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_otg/known_kcps2_loci_FBS_1Mb_EAS.tsv
#   merge time: 160.200ms
# 2024-10-06 01:47:57.028 Hail: INFO: Reading table to impute column types
# 2024-10-06 01:47:57.490 Hail: INFO: Finished type imputation
#   Loading field 'locus' as type str (imputed)
#   Loading field 'trait_efo' as type str (imputed)
#   Loading field 'study_id' as type str (imputed)
#   Loading field 'trait_efo_term' as type str (imputed)
#   Loading field 'trait_efo_category' as type str (imputed)
# 2024-10-06 01:47:59.288 Hail: INFO: Reading table to impute column types
# 2024-10-06 01:48:05.865 Hail: INFO: Finished type imputation
#   Loading field 'idx' as type int32 (imputed)
#   Loading field 'lead_locus' as type str (imputed)
#   Loading field 'region' as type str (imputed)
#   Loading field 'trait_efo' as type str (imputed)
#   Loading field 'trait_efo_category' as type str (imputed)
#   Loading field 'locus' as type str (imputed)
#   Loading field 'trait_efo_otg' as type str (imputed)
#   Loading field 'study_id' as type str (imputed)
#   Loading field 'trait_efo_term' as type str (imputed)
#   Loading field 'trait_efo_category_otg' as type str (imputed)
# 2024-10-06 01:48:15.042 Hail: INFO: merging 1001 files totalling 325.4K...
# 2024-10-06 01:48:15.139 Hail: INFO: while writing:
#     /n/holylfs05/LABS/kraft_lab/Lab/KCPS2/OTG/KCPS2_otg/known_kcps2_loci_FBS_1Mb_EAS.tsv
#   merge time: 96.892ms

# %%
trait_list = ["FBS"]
res = pd.DataFrame()
for i in range(len(trait_list)):
    trait = trait_list[i]
    print(trait)
    annotate_known_loci_1Mb_EAS(trait)
# Out:
# FBS
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /n/home03/yjee/.conda/envs/hail_envp/lib/python3.10/site-packages/pyranges/methods/init.py:45: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# [Stage 28:====================================================>(982 + 2) / 1000]
# +-------+---------------+-------------------------+---------------+
# |   idx | lead_locus    | region                  | trait_efo     |
# +-------+---------------+-------------------------+---------------+
# | int32 | locus<GRCh37> | interval<locus<GRCh37>> | str           |
# +-------+---------------+-------------------------+---------------+
# |     1 | 1:43453188    | [1:42453188-1:44453188) | "EFO_0004465" |
# |     1 | 1:43453188    | [1:42453188-1:44453188) | "EFO_0004465" |
# |     1 | 1:43453188    | [1:42453188-1:44453188) | "EFO_0004465" |
# +-------+---------------+-------------------------+---------------+
#
# +---------------------+--------------+---------------+------------------+
# | trait_efo_category  | locus_otg    | trait_efo_otg | study_id_otg     |
# +---------------------+--------------+---------------+------------------+
# | str                 | str          | str           | array<str>       |
# +---------------------+--------------+---------------+------------------+
# | "Other measurement" | "1:43455283" | "EFO_0004465" | ["GCST90278628"] |
# | "Other measurement" | "1:43805737" | "EFO_0004308" | ["GCST90278647"] |
# | "Other measurement" | "1:43884714" | "EFO_0004309" | ["GCST90255498"] |
# +---------------------+--------------+---------------+------------------+
#
# +-------------------------------------+-------------------------------------+
# | trait_efo_term                      | trait_efo_category_otg              |
# +-------------------------------------+-------------------------------------+
# | str                                 | str                                 |
# +-------------------------------------+-------------------------------------+
# | "fasting blood glucose measurement" | "fasting blood glucose measurement" |
# | "leukocyte count"                   | "leukocyte count"                   |
# | "platelet count"                    | "platelet count"                    |
# +-------------------------------------+-------------------------------------+
#
# +---------------+
# | locus         |
# +---------------+
# | locus<GRCh37> |
# +---------------+
# | 1:43455283    |
# | 1:43805737    |
# | 1:43884714    |
# +---------------+
# showing top 3 rows
# trait_efo
# 44
# 43
# 0
# 0
# trait_efo_category
# 0
# 87
# 0
# 0
# [Stage 32:====================================================>(985 + 2) / 1000]

# %%
# tmp - distance clumping

# %%
def agg_distance_clumping(
    locus_expr, alleles_expr, pvalue_expr, radius=500000, nlog_p=False, merge_overlapping_loci=True
):
    def _distance_clumping(f, lead_st_arr, remaining_st_arr):
        new_lead_st = remaining_st_arr[0]
        new_region = new_lead_st.region
        remaining_st_arr = remaining_st_arr.filter(lambda x: ~new_region.contains(x.lead_locus))

        # check whether a new region overlaps with previous ones
        overlapping_st = (
            lead_st_arr.find(lambda x: new_region.overlaps(x.region))
            if merge_overlapping_loci
            else hl.missing(new_lead_st.dtype)
        )
        lead_st_arr = hl.if_else(
            hl.is_defined(overlapping_st),
            lead_st_arr.map(
                lambda x: hl.if_else(
                    x == overlapping_st,
                    x.annotate(
                        region=hl.rbind(
                            overlapping_st.region,
                            lambda old_region: hl.interval(
                                hl.if_else(
                                    old_region.start < new_region.start,
                                    old_region.start,
                                    new_region.start,
                                ),
                                hl.if_else(old_region.end > new_region.end, old_region.end, new_region.end),
                            ),
                        )
                    ),
                    x,
                )
            ),
            lead_st_arr.append(new_lead_st),
        )
        converged = hl.len(remaining_st_arr) == 0

        return hl.if_else(converged, lead_st_arr, f(lead_st_arr, remaining_st_arr))

    # Modified from hl.expr.functions.sorted -- key is now another collection, not callable
    def _sorted(collection, key, reverse=False):
        def comp(left, right):
            return (
                hl.case()
                .when(hl.is_missing(left), False)
                .when(hl.is_missing(right), True)
                .when(reverse, hl._compare(right, left) < 0)
                .default(hl._compare(left, right) < 0)
            )

        return _sort_by(hl.zip(key, collection), lambda l, r: comp(l[0], r[0])).map(lambda elt: elt[1])

    # lead locus / region pair is necessary to check overlapping regions during the loop
    x = hl.agg.collect(
        hl.struct(
            st=hl.struct(
                lead_locus=locus_expr,
                lead_alleles=alleles_expr,
                region=locus_expr.window(radius, radius),
                lead_pvalue=pvalue_expr,
            )
        )
    )
    sorted_st = _sorted(x.st, x.st.lead_pvalue, reverse=nlog_p)
    t_struct = sorted_st[0].dtype

    run_distance_clumping = hl.experimental.define_function(
        lambda sorted_st: hl.experimental.loop(
            _distance_clumping, hl.tarray(t_struct), hl.empty_array(t_struct), sorted_st
        ),
        hl.tarray(t_struct),
    )
    return run_distance_clumping(sorted_st)

# %%
ht = ht.group_by(*list(mt.col_key)).aggregate(
            distance_clumps=agg_distance_clumping(
                ht.locus,
                ht.alleles,
                ht.Pvalue,
                radius=args.radius,
                nlog_p=False,
                merge_overlapping_loci=(not args.not_merge_overlapping_loci),
            )
        )
